# %%
# Creating README.md
with open("README.md", "w", encoding="utf-8") as readme_file:
    readme_file.write("""# Analysis and Visualization in Python: MAKEUP Project  
### Analysis and Visualization in Python: MAKEUP Project

---

## Project Description
This project focuses on analyzing and visualizing data from the **makeup** catalog, obtained through an API. It covers all stages — from data collection to creating charts that help explore key catalog features and identify relationships.

---

## File Structure
- **JSON Files:**
  - `makeup_all_products.json`: JSON file containing all collected data.  

- **IPYNB Files:**
  1. `makeup_api_loading.ipynb`: Loading and saving data from the API.
  2. `makeup_research_dataset.ipynb`: Importing and conducting an initial exploration of the data.
  3. `makeup_data_preparation.ipynb`: Processing and preparing the data.
  4. `makeup_color_table.ipynb`: Creating a color table for visualizations.
  5. `makeup_project_visualization.ipynb`: Building analytics charts.
  6. `makeup_project_visualization_unloading_png.ipynb`: Exporting charts as `.png` files.
  7. `makeup_presentation_pdf.ipynb`: Creating the presentation `Makeup_analysis_presentation.pdf`.

- **CSV Files:**
  - `makeup_valid_prices.csv`: Products with valid prices.
  - `makeup_no_prices.csv`: Products with undefined prices.
  - `makeup_additional_info.csv`: Supplementary information.
  - `makeup_valid_prices_filled.csv`: Data with missing values filled.
  - `makeup_valid_prices_filled_columns.csv`: Data with additional columns for analysis.

---

## Technologies Used
- **Python:** Pandas, Matplotlib, Plotly
- **API:** Data collection via HTTP requests
- **Data Processing:** Normalization, filtering, analysis
- **Visualization:** Charts, heatmaps, histograms, and more
""")

# Creating Pipeline.md
with open("Pipeline.md", "w", encoding="utf-8") as pipeline_file:
    pipeline_file.write("""## Pipeline (Project Workflow)

### **1. makeup_api_loading.ipynb**
- Loading data from the [Makeup API](https://makeup-api.herokuapp.com/api/v1/products.json).
- Saving data to a JSON file: `makeup_all_products.json`.

---

### **2. makeup_research_dataset.ipynb**
- Importing data from `makeup_all_products.json`.
- Initial analysis of structure, content, and properties of the data.

---

### **3. makeup_data_preparation.ipynb**
- Loading and preparing data for analysis.
- Splitting into separate datasets:
  - **`makeup_valid_prices.csv`**
  - **`makeup_no_prices.csv`**
  - **`makeup_additional_info.csv`**
- Filling missing values in key columns.
- Adding new columns:
  - `categorize_price`, `brand_popularity`, `category_product_type`.

---

### **4. makeup_color_table.ipynb**
- Creating a color palette.
- A color table for visual analytical charts.

---

### **5. makeup_project_visualization.ipynb**
#### Chart Building:
1. **Number of unique product names, brands, categories, and types.**  
2. **Number of brands and products by category-product type combinations.**  
3. **Number of items by price category.**  
4. **Share of price categories.**  
5. **Price statistics.**  
6. **Dependency between price and rating.**  
7. **Distribution of product ratings.**  
8. **Share of products with and without ratings.**  
9. **Count of types, categories, and brands with ratings.**  
10. **Product type: number of products, average rating, average price.**  
11. **Category: number of products, average rating, average price.**  
12. **Relationships between product types and their categories.**  
13. **Brands by categories and product types with ratings.**  
14. **All brands: number of products, average rating, average price.**  
15. **Coverage of the top 20 brands in product distribution.**  
16. **Visualization of an excluded product.**  
17. **Top 20 brands offering the most products.**  
18. **Price distribution for the top 20 leading brands.**  
19. **Product distribution across price categories among top 20 brands.**  
20. **Product distribution across category-product types among top 20 brands.**

---

### **6. makeup_project_visualization_unloading_png.ipynb**
- A folder `makeup_visualizations_png` was created.
- Charts were exported as `.png` files for convenient review and demonstration.

---

### **7. makeup_presentation_pdf.ipynb**
- Creating the presentation `Makeup_analysis_presentation.pdf`.
""")

# %%
import os

# Function to list files and folders
def list_files_and_folders(path="."):
    for root, dirs, files in os.walk(path):
        print(f"📂 Directory: {root}")
        print("📁 Folders:")
        for dir_name in dirs:
            print(f"  - {dir_name}")
        print("📄 Files:")
        for file_name in files:
            print(f"  - {file_name}")
        print("---")

# Call the function for the current directory
list_files_and_folders()
# Out:
# 📂 Directory: .
# 📁 Folders:
#   - .ipynb_checkpoints
#   - makeup_visualizations_png
# 📄 Files:
#   - 1_makeup_api_loading.ipynb
#   - 2_makeup_research_dataset.ipynb
#   - 3_makeup_data_preparation.ipynb
#   - 4_makeup_color_table.ipynb
#   - 5_makeup_project_visualization.ipynb
#   - 6_makeup_project_visualization_unloading_png.ipynb
#   - 7_makeup_presentation_pdf.ipynb
#   - 8_makeup_README_Pipeline.ipynb
#   - color_table.html
#   - color_table.png
#   - makeup_additional_info.csv
#   - makeup_all_products.json
#   - Makeup_analysis_presentation.pdf
#   - Makeup_analysis_presentation.pptx
#   - makeup_no_prices.csv
#   - makeup_valid_prices.csv
#   - makeup_valid_prices_filled.csv
#   - makeup_valid_prices_filled_columns.csv
#   - Pipeline.md
#   - README.md
# ---
# 📂 Directory: .\.ipynb_checkpoints
# 📁 Folders:
# 📄 Files:
#   - 1_makeup_api_loading-checkpoint.ipynb
#   - 2_makeup_research_dataset-checkpoint.ipynb
#   - 3_makeup_data_preparation-checkpoint.ipynb
#   - 4_makeup_color_table-checkpoint.ipynb
#   - 5_makeup_project_visualization-checkpoint.ipynb
#   - 6_makeup_project_visualization_unloading_png-checkpoint.ipynb
#   - 7_makeup_presentation_pdf-checkpoint.ipynb
#   - 8_makeup_README_Pipeline-checkpoint.ipynb
# ---
# 📂 Directory: .\makeup_visualizations_png
# 📁 Folders:
# 📄 Files:
#   - 10_Product_Type.png
#   - 11_Category.png
#   - 12_Product_Types_and_Categories_Sankey.png
#   - 13_Brands_Categories_Product_Type_Ratings_Treemap.png
#   - 14_All_brands.png
#   - 15_16_Top_Brands_in_Product.png
#   - 17_Top_Brands_analysis.png
#   - 18_Top_Brands_Price_statistics.png
#   - 19_Top_Brands_Price_Categor.png
#   - 1_Number_of_unique_values.png
#   - 20_Top_Brands_Across_Category_Product_Heatmap.png
#   - 2_Number_brands_products_category_product_type.png
#   - 3_4_5_6_Price.png
#   - 7_8_9_Rating.png
# ---

# %%
# Updating README.md
with open("README.md", "w", encoding="utf-8") as readme_file:
    readme_file.write("""# Analysis and Visualization in Python: MAKEUP Project  
### Analysis and Visualization in Python: MAKEUP Project

---

## Project Description
This project focuses on analyzing and visualizing data from the **makeup** catalog, obtained through an API. It covers all stages — from data collection to creating charts that help explore key catalog features and identify relationships.

---

## File Structure
- **JSON Files:**
  - `makeup_all_products.json`: JSON file containing all collected data.  

- **IPYNB Files:**
  1. `makeup_api_loading.ipynb`: Loading and saving data from the API.
  2. `makeup_research_dataset.ipynb`: Importing and conducting an initial exploration of the data.
  3. `makeup_data_preparation.ipynb`: Processing and preparing the data.
  4. `makeup_color_table.ipynb`: Creating a color table for visualizations.
  5. `makeup_project_visualization.ipynb`: Building charts for analytics.
  6. `makeup_project_visualization_unloading_png.ipynb`: Exporting charts as `.png` files.
  7. `makeup_presentation_pdf.ipynb`: Creating the presentation `Makeup_analysis_presentation.pdf`.
  8. `makeup_README_Pipeline.ipynb`: Creating and refining README.md and Pipeline.md.

- **CSV Files:**
  - `makeup_valid_prices.csv`: Products with valid prices.
  - `makeup_no_prices.csv`: Products with undefined prices.
  - `makeup_additional_info.csv`: Supplementary information.
  - `makeup_valid_prices_filled.csv`: Data with filled missing values.
  - `makeup_valid_prices_filled_columns.csv`: Data with additional columns for analysis.

- **Other Files:**
  - `color_table.html`: Color table in HTML format.
  - `color_table.png`: Color table as an image.
  - `Makeup_analysis_presentation.pdf`: Presentation in PDF format.
  - `Makeup_analysis_presentation.pptx`: Presentation in PPTX format.

---

## Technologies Used
- **Python:** Pandas, Matplotlib, Plotly
- **API:** Data collection via HTTP requests
- **Data Processing:** Normalization, filtering, analysis
- **Visualization:** Charts, heatmaps, histograms, and more
""")

# Updating Pipeline.md
with open("Pipeline.md", "w", encoding="utf-8") as pipeline_file:
    pipeline_file.write("""## Pipeline (Project Workflow)

### **1. makeup_api_loading.ipynb**
- Loading data from the [Makeup API](https://makeup-api.herokuapp.com/api/v1/products.json).
- Saving data to a JSON file: `makeup_all_products.json`.

---

### **2. makeup_research_dataset.ipynb**
- Importing data from `makeup_all_products.json`.
- Initial analysis of structure, content, and properties of the data.

---

### **3. makeup_data_preparation.ipynb**
- Loading and preparing data for analysis.
- Splitting into separate datasets:
  - **`makeup_valid_prices.csv`**
  - **`makeup_no_prices.csv`**
  - **`makeup_additional_info.csv`**
- Filling missing values in key columns.
- Adding new columns:
  - `categorize_price`, `brand_popularity`, `category_product_type`.

---

### **4. makeup_color_table.ipynb**
- Creating a color palette.
- A color table for visual analytical charts.

---

### **5. makeup_project_visualization.ipynb**
#### Chart Building:
1. **Number of unique product names, brands, categories, and types.**  
2. **Number of brands and products by category-product type combinations.**  
3. **Number of items by price category.**  
4. **Share of price categories.**  
5. **Price statistics.**  
6. **Dependency between price and rating.**  
7. **Distribution of product ratings.**  
8. **Share of products with and without ratings.**  
9. **Count of types, categories, and brands with ratings.**  
10. **Product type: number of products, average rating, average price.**  
11. **Category: number of products, average rating, average price.**  
12. **Relationships between product types and their categories.**  
13. **Brands by categories and product types with ratings.**  
14. **All brands: number of products, average rating, average price.**  
15. **Coverage of the top 20 brands in product distribution.**  
16. **Visualization of an excluded product.**  
17. **Top 20 brands offering the most products.**  
18. **Price distribution for the top 20 leading brands.**  
19. **Product distribution across price categories among top 20 brands.**  
20. **Product distribution across category-product types among top 20 brands.**

---

### **6. makeup_project_visualization_unloading_png.ipynb**
- A folder `makeup_visualizations_png` was created.
- Charts were exported as `.png` files for convenient review and demonstration.

---

### **7. makeup_presentation_pdf.ipynb**
- Creating the presentation `Makeup_analysis_presentation.pdf`.

---

### **8. makeup_README_Pipeline.ipynb**
- Creating and refining README.md and Pipeline.md.
""")
